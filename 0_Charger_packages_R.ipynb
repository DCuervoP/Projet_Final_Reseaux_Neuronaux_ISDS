# %%
# %load_ext rpy2.ipython

# %%
import rpy2.robjects as ro
from rpy2.robjects import r, pandas2ri

from google.colab import drive #pour travailler sur colab
drive.mount('/content/drive')
path ='/content/drive/MyDrive/Maestria_Sorbonne/M2/2 s2/2 Reseaux Neuronaux/Project/packages'
# Out:
# Mounted at /content/drive

# %%
r.assign("path", path)  #path in r
# Out:
# <rpy2.robjects.vectors.StrVector object at 0x7a6a84a55c80> [RTYPES.STRSXP]
# R classes: ('character',)
# ['/content/drive/MyDrive/Maestria_Sorbonne/M2/2 s2...]

# %%
# %%R
# install.packages("furrr", lib = path)
# install.packages("rsample", lib = path)
# install.packages("e1071",lib = path)
# install.packages("caret", lib = path)
# install.packages("NeuralNetTools", lib = path)
# install.packages("patchwork", lib = path)
# install.packages("nnet", lib = path)
# install.packages("kohonen", lib = path)
# install.packages('dplyr', lib = path)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/listenv_0.9.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 36600 bytes (35 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# !ls "/content/drive/MyDrive/Maestria_Sorbonne/M2/2 s2/2 Reseaux Neuronaux/Project/packages"
# Out:
# caret	 foreach       gower	  lava		  numDeriv    prodlim	 rsample   warp
# clock	 furrr	       hardhat	  listenv	  parallelly  progressr  shape
# diagram  future        ipred	  ModelMetrics	  patchwork   proxy	 slider
# dplyr	 future.apply  iterators  NeuralNetTools  plyr	      recipes	 SQUAREM
# e1071	 globals       kohonen	  nnet		  pROC	      reshape2	 timeDate
